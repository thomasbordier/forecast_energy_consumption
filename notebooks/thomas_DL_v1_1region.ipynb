# %%
import pandas as pd 
import tensorflow as tf

# %%
df = pd.read_csv("../raw_data/df_3M_rows.csv").drop(['Unnamed: 0'], axis=1)
df.head(200)
display(df)
# Out:
# /var/folders/s8/4k62tj0j2qz1lr9dt431vynr0000gn/T/ipykernel_7134/3026719203.py:1: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../raw_data/df_3M_rows.csv").drop(['Unnamed: 0'], axis=1)
#          metropolitan_area_code                 date  energy_consumption  \
# 0                             0  2017-02-13 02:30:00              4625.0
# 1                             0  2017-02-13 02:45:00              4571.0
# 2                             0  2017-02-13 03:00:00                 NaN
# 3                             0  2017-02-13 03:15:00              4524.0
# 4                             0  2017-02-13 03:30:00              4489.0
# ...                         ...                  ...                 ...
# 2909681                      16  2021-12-31 22:45:00               114.0
# 2909682                      16  2021-12-31 23:00:00                 NaN
# ...

# %%
df_area_spe = df_weather[df_weather.metropolitan_area_code==2]#.reset_index(drop=True)
df_area_spe
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [78], in <cell line: 2>()
#       1 df_area_spe = df_weather[df_weather.metropolitan_area_code==2]#.reset_index(drop=True)
# ----> 2 df_area_spe.list()
#
# File ~/.pyenv/versions/3.8.13/envs/forecast_energy_consumption/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'list'

# %%
X = df_area_spe[['date','T2M','T2MDEW','T2MWET','QV2M','RH2M','PRECTOTCORR']]
X.describe().transpose()
# Out:
#                count       mean        std    min    25%    50%    75%     max
# T2M          78477.0  15.100776   8.428398  -3.84   8.43  14.26  21.10   40.98
# T2MDEW       78477.0   8.570915   5.229623  -9.99   5.00   8.77  12.58   21.84
# T2MWET       78477.0  11.835826   6.315626  -4.93   6.96  11.81  17.02   27.11
# QV2M         78477.0   7.532666   2.572212   1.77   5.55   7.26   9.34   16.85
# RH2M         78477.0  69.899879  22.176433  13.25  52.38  73.44  89.38  100.00
# PRECTOTCORR  78477.0   0.062767   0.336522   0.00   0.00   0.00   0.01   12.08

# %%
from tensorflow.keras.layers import Masking
from tensorflow.keras.preprocessing.sequence import pad_sequences


X = pad_sequences(X, dtype='float32', padding='post', value=-1000)

model = Sequential()
model.add(layers.Masking(mask_value=-1000, input_shape=(4,3)))
model.add(layers.SimpleRNN(units=2, activation='tanh'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='linear'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [75], in <cell line: 5>()
#       1 from tensorflow.keras.layers import Masking
#       2 from tensorflow.keras.preprocessing.sequence import pad_sequences
# ----> 5 X = pad_sequences(X, dtype='float32', padding='post', value=-1000)
#       7 model = Sequential()
#       8 model.add(layers.Masking(mask_value=-1000, input_shape=(4,3)))
#
# File ~/.pyenv/versions/3.8.13/envs/forecast_energy_consumption/lib/python3.8/site-packages/tensorflow/python/keras/preprocessing/sequence.py:152, in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#      88 @keras_export('keras.preprocessing.sequence.pad_sequences')
#      89 def pad_sequences(sequences, maxlen=None, dtype='int32',
#      90                   padding='pre', truncating='pre', value=0.):
#      91   """Pads sequences to the same length.
#      92
# ...
